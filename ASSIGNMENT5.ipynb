# %% [markdown]
# <a href="https://colab.research.google.com/github/Munyekiliz/pythonProject5/blob/master/ASSIGNMENT5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
options = ''# declaring an empty string
            #display the options
while options != "Q":

  options = input("Enter the options  [P, C, F, NM, KMS, KM, M, CM, MA, Y, MB, IN, CM2, Q]?")
  if options == "P":
    print("[P] Print Options")
    print("[C] Convert from Celcius")
    print("[F] Convert from Fahrenheit")
    print("[NM] Convert from Nautical_Mile")
    print("[KMS] Convert from KMS")
    print("[KM] Convert from Kilometers")
    print("[M] Convert from Miles")
    print("[CM] Convert from Centimeters")
    print("[MA] Convert from Meters")
    print("[Y] Convert from Yard")
    print("[MB] Convert from Meters")
    print("[In] Convert from Inches")
    print("[CM2] Convert from Centimeters")
   
    print("[Q] Quit")

    print()

  elif options == "C":
      #Temperature from Fahrenheit to Celsius 
      celsius = 37.5
      fahrenheit = celsius * 1.8 + 32
      celsius = float(input('Enter temp in celsuis'))
      fahrenheit = float(input('Enter temp in fahrenheit'))
      print('%0.1f celsius equal to %0.3f Farenheit'%(celsius,fahrenheit))
      #print('%0.3f farenheit equal to %0.1f Celsius'%(fahrenheit,celsius))

  elif options == "F":
     fahrenheit = celsius * 1.8 + 32 
     celsius = 37.5
     fahrenheit = float(input('Enter temp in fahrenheit'))
     celsius = float(input('Enter temp in celsuis'))
     #print('%0.1f celsius equal to %0.3f Farenheit'%(celsius,fahrenheit))
     print('%0.3f farenheit equal to %0.1f Celsius'%(fahrenheit,celsius))
 

  elif options == "KM":
    
         #convert from kilometer to miles
         kilo_meter = float(input('Enter distance in Kilometers: '))
         miles = float(input('Enter distance in Miles')) 

         #conversion factor
         KMconv_fac = 0.621371

         kilo_meter = miles / KMconv_fac
         miles = kilo_meter * KMconv_fac
         #kilo_meter = float(input('Enter distance in kilo_meters: '))
         print('%0.3f kilo_meter is equal to %0.3f miles' %(kilo_meter,miles))
         #print('%0.3f miles is equal to %0.3f Kilo_meter' %(miles,kilometer))

  elif options == "M":
         #Convert from miles to kilometer
          miles = float(input('Enter distance in miles'))
          kilo_meter = float(input('Enter distance in Kilometers: '))

          KMconv_fac = 0.621371
          miles = kilo_meter * KMconv_fac
          kilo_meter = miles / KMconv_fac
          print('%0.3f miles is equal to %0.3f Kilo_meter' %(miles,kilo_meter))
          #print('%0.3f miles is equal to %0.3f Kilo_meter' %(kilo_meter,miles))

  elif options == "IN":

     #Convert Inches to Centimeters and back
      inches = float(input('Enter distance in Inches'))
      centimeters = float(input('Enter distance in Centimeters'))
 
     #conversion factor
      CMconv_fac = 2.54
      inches = centimeters * CMconv_fac
      centimeters = inches / CMconv_fac
 
      #print('%0.3f centimeters is equal to %0.3f inches'%(inches,centimeters))
      print('%0.3f inches is equal to %0.3f centimeters'%(inches,centimeters))

  elif options == "CM2":

      centimeters = float(input('Enter distance in Centimeters'))
      inches = float(input('Enter distance in Inches'))
     
     #conversion factor
      CMconv_fac = 2.54
      inches = centimeters * CMconv_fac
      centimeters = inches / CMconv_fac
 
      print('%0.3f centimeters is equal to %0.3f inches'%(centimeters,inches))
     #print('%0.3f inches is equal to %0.3f centimeters'%(centimeters,inches))
   

  elif options == "NM":
    #Convert Nautical Miles to Kilometers and back
    Nautical = float(input('Enter distance in Nautical miles: '))
    KMS = float(input('Enter distance in KMS:' ))
    
    #conversion factor
    NMconv_factor = 1.852

    Nautical_Mile = KMS * NMconv_factor
    KILOMETERS = Nautical_Mile / NMconv_factor

    print('%0.3fNautical_Mile equal to %0.03f Kilometers' %(Nautical_Mile,KMS))
    #print('%0.3fkilometers equal to %0.3f Nautical Miles' %(Nautical_Mile, KILOMETERS))

  elif options == "KMS":
    KMS = float(input('Enter distance in KMS:' ))
    Nautical_Mile = float(input('Enter distance in Nautical miles: '))
    #conversion factor
    NMconv_factor = 1.852

    Nautical_Mile = KMS * NMconv_factor
    KILOMETERS = Nautical_Mile / NMconv_factor

    #print('%0.3fNautical_Miles equal to %0.03f Kilometers' %(KMS, Nautical_Mile))
    print('%0.3fkilometers equal to %0.3f Nautical Miles' %(KILOMETERS,Nautical_Mile))

  elif options == "Y":
    #Convert Yard to Meter and back
    yard = float(input('Enter distance in Yard'))
    meter = float(input('Enter distance in meter'))
 
   #conversion factor
    Yconv_fac = 0.9144
    meters = yard * Yconv_fac
    yard = meters / Yconv_fac
 
    print('%0.3f yard is equal to %0.3f meters'%(yard,meters))
    #print('%0.3f meters is equal to %0.3f yard'%(meters,yard)) 

  elif options == "MB":

    meter = float(input('Enter distance in meter'))
    yard = float(input('Enter distance in Yard'))
    
 
   #conversion factor
    Yconv_fac = 0.9144
    yard = meters / Yconv_fac
    meters = yard * Yconv_fac
    
 
    #print('%0.3f yard is equal to %0.3f meters'%(yard,meters,))
    print('%0.3f meters is equal to %0.3f yard'%(meters,yard)) 

  elif options == "CM":
    #Convert Centimeters to meters and back

    centimeter = float(input('Enter length in Centimeters: '))
    meters = float(input('Enter length in Meters'))
 
    meters = float(centimeter/100)
    centimeter = float(meters*100)
    print('%0.3f Centimeter is equal to %0.3f Meters' %(centimeter, meters))
    #print('%0.3f Meters is equal to %0.3f Centimeters' %(meters, centimeter))

  elif options =="MA":
    
    meters = float(input('Enter length in Meters'))
    centimeter = float(input('Enter length in Centimeters: '))
   
 
    meters = float(centimeter/100)
    centimeter = float(meters*100)
    #print('%0.3f Centimeter is equal to %0.3f Meters' %(meters,centimeter))
    print('%0.3f Meters is equal to %0.3f Centimeters' %(meters, centimeter))

  elif options == "Q":
      print("Quit")
      break
# Out:
# Enter the options  [P, C, F, NM, KMS, KM, M, CM, MA, Y, MB, IN, CM2, Q]?C
# Enter temp in celsuis37.5
# Enter temp in fahrenheit99.5
# 37.5 celsius equal to 99.500 Farenheit
# Enter the options  [P, C, F, NM, KMS, KM, M, CM, MA, Y, MB, IN, CM2, Q]?F
# Enter temp in fahrenheit99.5
# Enter temp in celsuis37.5
# 99.500 farenheit equal to 37.5 Celsius
# Enter the options  [P, C, F, NM, KMS, KM, M, CM, MA, Y, MB, IN, CM2, Q]?KM
# Enter distance in Kilometers: 2
# Enter distance in Miles4
# 6.437 kilo_meter is equal to 4.000 miles
# Enter the options  [P, C, F, NM, KMS, KM, M, CM, MA, Y, MB, IN, CM2, Q]?M
# Enter distance in miles4
# Enter distance in Kilometers: 2
# 1.243 miles is equal to 2.000 Kilo_meter
# Enter the options  [P, C, F, NM, KMS, KM, M, CM, MA, Y, MB, IN, CM2, Q]?IN
# Enter distance in Inches2
# Enter distance in Centimeters3
# 7.620 inches is equal to 3.000 centimeters
# Enter the options  [P, C, F, NM, KMS, KM, M, CM, MA, Y, MB, IN, CM2, Q]?CM2
# ...
